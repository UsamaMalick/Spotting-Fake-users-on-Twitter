# %%
import sys
import time
import random

import numpy as np
import pandas as pd

# %%
gen_users = pd.read_csv('dataset/users.csv')
gen_tweets = pd.read_csv('dataset/tweets.csv')

# %%
gen_users
# Out:
#             id             name     screen_name  statuses_count  \
# 0    488351800             MASC     angeli_masc           60463
# 1     75506408     Karan Baweja          krnbwj             135
# 2     37407255   অগ্নিভ নিয়োগী         Aagan86          283536
# 3   1664307984    laurel daniel   _laureldaniel            1770
# 4    308236961       King Devin    _KingDevin25            4790
# ..         ...              ...             ...             ...
# 95    85203320              Tee  boyzinthehoood            8860
# 96  1617515642            Sofia    sofialozano_           12502
# 97  3013481653       augustine   drizzlingh0ran            1189
# 98   614770385               JB       brockly36             103
# 99   221187678       HARIS KHAN   KingKhanBeats           48392
#
#     followers_count  friends_count  favourites_count  listed_count  \
# 0               568            387             15599             1
# ...

# %%
gen_tweets
# Out:
#                         id                                               text  \
# 0       594073273480130560  How Randolph Hodgson and Neals Yard Dairy gave...
# 1       594066507723833345  “Twitter’s multi-billion dollar mistake happen...
# 2       593739179655323649  The evolution of advertising in the legal sect...
# 3       593737857149345792  RT @rorysutherland: Plan Bee - http://t.co/030...
# 4       593282967134466051  RT @davewiner: Some say the Other Internet is ...
# ...                    ...                                                ...
# 248528  573687545311162368           RT @FreestyIeRaps: They killed this hoe
# 248529  573687532149424128   RT @QuiNigga_: "@SavageBars: HE KILLED IT AGAIN
# 248530  573687515342835712                    RT @FreestyIeRaps: HE KILLED IT
# 248531  573659786216079360  RT @DreecNation: S/o to my new follower @QuiNi...
# 248532  573650510756069376                                                NaN
#
# ...
